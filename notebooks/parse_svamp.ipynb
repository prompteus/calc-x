# %%
from typing import Iterable
import warnings

import pandas as pd
import sympy
import lark

import gadgets

# %%
df = pd.read_json('../data/svamp/svamp.json')
df.columns = df.columns.str.lower()
df
# Out:
#             id                                               body  \
# 0       chal-1  Each pack of dvds costs 76 dollars. If there i...
# 1       chal-2  Dan had $ 3 left with him after he bought a ca...
# 2       chal-3  Paco had 26 salty cookies and 17 sweet cookies...
# 3       chal-4  43 children were riding on the bus. At the bus...
# 4       chal-5  28 children were riding on the bus. At the bus...
# ..         ...                                                ...
# 995   chal-996  Paige was helping her mom plant flowers and to...
# 996   chal-997  At the zoo, a cage had 3 snakes and 75 alligat...
# 997   chal-998  Paige was helping her mom plant flowers and to...
# 998   chal-999  Mary is baking a cake. The recipe calls for 7 ...
# 999  chal-1000  The grasshopper and the frog had a jumping con...
#
#                                               question  \
# 0        How much do you have to pay to buy each pack?
# 1                     How much did the candy bar cost?
# 2           How many salty cookies did Paco have left?
# 3    How many children got off the bus at the bus s...
# 4    How many more children got on the bus than tho...
# ..                                                 ...
# 995                How many flower beds did they have?
# 996               How many alligators were not hiding?
# 997                    How many flowers did they grow?
# 998  How many more cups of sugar does she need to add?
# 999                         How far did the frog jump?
#
#                        equation  answer             type
# 0               ( 76.0 - 25.0 )      51      Subtraction
# 1                 ( 4.0 - 3.0 )       1      Subtraction
# 2                ( 26.0 - 9.0 )      17      Subtraction
# 3               ( 43.0 - 21.0 )      22      Subtraction
# 4               ( 30.0 - 28.0 )       2      Subtraction
# ..                          ...     ...              ...
# 995             ( 36.0 / 12.0 )       3  Common-Division
# 996             ( 75.0 - 19.0 )      56      Subtraction
# 997  ( 60.0 * ( 55.0 / 15.0 ) )     220   Multiplication
# 998               ( 7.0 - 4.0 )       3      Subtraction
# 999              ( 13.0 - 2.0 )      11      Subtraction
#
# [1000 rows x 6 columns]

# %%
df["question"].str[0].value_counts()
# Out:
# question
# H    988
# W      6
# A      4
# T      2
# Name: count, dtype: int64

# %%
df["body"].str[-1].value_counts()
# Out:
# body
# .    642
# s    145
# y     45
# t     34
# k     24
# e     17
# w     14
# r     14
# g     12
# d     10
# l      9
# n      6
# a      6
# m      4
# x      4
# p      3
# u      3
# f      2
# 7      2
# 5      1
# 3      1
# 8      1
# 2      1
# Name: count, dtype: int64

# %%
def merge_body_with_question(body: str, question: str):
    if body.endswith("."):
        return body + " " + question
    return body + ", " + question[0].lower() + question[1:]

# %%
df["question"] = df.apply(lambda row: merge_body_with_question(row["body"], row["question"]), axis=1)
del df["body"]

# %%
df
# Out:
#             id                                           question  \
# 0       chal-1  Each pack of dvds costs 76 dollars. If there i...
# 1       chal-2  Dan had $ 3 left with him after he bought a ca...
# 2       chal-3  Paco had 26 salty cookies and 17 sweet cookies...
# 3       chal-4  43 children were riding on the bus. At the bus...
# 4       chal-5  28 children were riding on the bus. At the bus...
# ..         ...                                                ...
# 995   chal-996  Paige was helping her mom plant flowers and to...
# 996   chal-997  At the zoo, a cage had 3 snakes and 75 alligat...
# 997   chal-998  Paige was helping her mom plant flowers and to...
# 998   chal-999  Mary is baking a cake. The recipe calls for 7 ...
# 999  chal-1000  The grasshopper and the frog had a jumping con...
#
#                        equation  answer             type
# 0               ( 76.0 - 25.0 )      51      Subtraction
# 1                 ( 4.0 - 3.0 )       1      Subtraction
# 2                ( 26.0 - 9.0 )      17      Subtraction
# 3               ( 43.0 - 21.0 )      22      Subtraction
# 4               ( 30.0 - 28.0 )       2      Subtraction
# ..                          ...     ...              ...
# 995             ( 36.0 / 12.0 )       3  Common-Division
# 996             ( 75.0 - 19.0 )      56      Subtraction
# 997  ( 60.0 * ( 55.0 / 15.0 ) )     220   Multiplication
# 998               ( 7.0 - 4.0 )       3      Subtraction
# 999              ( 13.0 - 2.0 )      11      Subtraction
#
# [1000 rows x 5 columns]

# %%
grammar = """
# ?start: expr

# ?expr: neg

# ?atom: num
    | implicit_mul
    | "(" expr ")"

implicit_mul: num ( "(" expr ")" )+
            | "(" expr ")" ( "(" expr ")" )+

# ?neg: add
    | "-" neg -> neg
    | "-" add -> neg
# ?add: sub
    | sub ("+" sub)+ -> add
# ?sub: mul
    | mul ("-" mul)+ -> sub
# ?mul: div
    | div ("*" div)+ -> mul
# ?div: pow
    | pow ("/" pow)+ -> div
# ?pow: perc
    | perc ("**" perc)+ -> pow
# ?perc: atom "%" -> perc
     | atom
# ?num: SIGNED_NUMBER

# %import common.SIGNED_NUMBER
# %import common.WS
# %ignore WS
"""

# %%
class TreeEvaluator:

    def __init__(self, calc: gadgets.gadget.Calculator, parser: lark.Lark) -> None:
        self.cache = {}
        self.calc = calc
        self.parser = parser

    def eval_tree(self, tree: lark.Tree | lark.Token) -> tuple[str, sympy.Expr]:
        if tree not in self.cache:
            self.cache[tree] = self._eval_tree(tree)
        return self.cache[tree]

    def _eval_tree(self, tree: lark.Tree | lark.Token) -> tuple[str, sympy.Expr]:
        if isinstance(tree, lark.Token):
            if tree.type in ("SIGNED_NUMBER", "NUMBER"):
                return None, self.calc.evaluate(tree.value)
            else:
                raise ValueError(f"unknown token {tree}")
        
        assert isinstance(tree.data, str)
        operation = tree.data
        args_nodes = tree.children
        args = [self._format_arg(self.eval_tree(arg_node)[1]) for arg_node in args_nodes]
        inputs = self._format_op(operation, args)
        return inputs, self.calc.evaluate(inputs)
    
    def _format_op(self, op: str, args: list[str]) -> str:
        if op == "neg":
            assert len(args) == 1
            return "-" + args[0]
        if op == "add" or op == "implicit_add":
            return " + ".join(args)  
        if op == "sub":
            return " - ".join(args)
        if op == "mul" or op == "implicit_mul":
            return " * ".join(args)
        if op == "div":
            return " / ".join(args)
        if op == "pow":
            return " ** ".join(args)
        if op == "perc":
            assert len(args) == 1
            return f"{args[0]} / 100"
        raise ValueError(f"unknown operation {op}")

    def _format_arg(self, value_expr: sympy.Number) -> str:
        value_str = self.calc.format_sympy_number(value_expr, add_approx=False)
        if isinstance(value_expr, sympy.core.function.Application):
            return value_str
        if isinstance(value_expr, (sympy.Float, sympy.Integer, sympy.NumberSymbol)):
            if value_expr < 0:
                return "(" + value_str + ")"
            return value_str
        if isinstance(value_expr, sympy.Rational):
            return "(" + value_str + ")"
        if isinstance(value_expr, (sympy.Mul, sympy.Pow, sympy.Add)):
            return "(" + value_str + ")"
        warnings.warn(f"weird value type {type(value_expr)} for {value_expr} (string: '{value_str}')")
        return "(" + value_str + ")"

    def dfs(self, tree: lark.Tree | lark.Token) -> Iterable[lark.Tree | lark.Token]:
        if isinstance(tree, lark.Tree):
            for child in tree.children:
                yield from self.dfs(child)
        yield tree

    def expr_to_steps(self, expr: str, drop_repeated: bool = True) -> tuple[list[gadgets.datatypes.Interaction], sympy.Expr]:
        tree = self.parser.parse(expr)
        steps = []
        for subtree in self.dfs(tree):
            step = self.eval_tree(subtree)
            if step is None:
                continue
            if step[0] is None:
                continue
            inputs, output_expr = step
            interaction = gadgets.datatypes.Interaction(
                gadget_id="calculator",
                inputs=inputs,
                outputs=self.calc.format_sympy_number(output_expr),
            )
            if drop_repeated and interaction in steps:
                continue
            steps.append(interaction)
            
        _, result = self.eval_tree(tree)
        return steps, result

# %%
calc = gadgets.gadget.Calculator()

parser = lark.Lark(grammar)
tree_evaluator = TreeEvaluator(calc, parser)

df["chain"], df["evaluated_result"] = zip(*df["equation"].apply(tree_evaluator.expr_to_steps))
df
# Out:
#             id                                           question  \
# 0       chal-1  Each pack of dvds costs 76 dollars. If there i...
# 1       chal-2  Dan had $ 3 left with him after he bought a ca...
# 2       chal-3  Paco had 26 salty cookies and 17 sweet cookies...
# 3       chal-4  43 children were riding on the bus. At the bus...
# 4       chal-5  28 children were riding on the bus. At the bus...
# ..         ...                                                ...
# 995   chal-996  Paige was helping her mom plant flowers and to...
# 996   chal-997  At the zoo, a cage had 3 snakes and 75 alligat...
# 997   chal-998  Paige was helping her mom plant flowers and to...
# 998   chal-999  Mary is baking a cake. The recipe calls for 7 ...
# 999  chal-1000  The grasshopper and the frog had a jumping con...
#
#                        equation  answer             type  \
# 0               ( 76.0 - 25.0 )      51      Subtraction
# 1                 ( 4.0 - 3.0 )       1      Subtraction
# 2                ( 26.0 - 9.0 )      17      Subtraction
# 3               ( 43.0 - 21.0 )      22      Subtraction
# 4               ( 30.0 - 28.0 )       2      Subtraction
# ..                          ...     ...              ...
# 995             ( 36.0 / 12.0 )       3  Common-Division
# 996             ( 75.0 - 19.0 )      56      Subtraction
# 997  ( 60.0 * ( 55.0 / 15.0 ) )     220   Multiplication
# 998               ( 7.0 - 4.0 )       3      Subtraction
# 999              ( 13.0 - 2.0 )      11      Subtraction
#
#                                                  chain evaluated_result
# 0    [gadget_id='calculator' inputs='76 - 25' outpu...               51
# 1    [gadget_id='calculator' inputs='4 - 3' outputs...                1
# 2    [gadget_id='calculator' inputs='26 - 9' output...               17
# 3    [gadget_id='calculator' inputs='43 - 21' outpu...               22
# 4    [gadget_id='calculator' inputs='30 - 28' outpu...                2
# ..                                                 ...              ...
# 995  [gadget_id='calculator' inputs='36 / 12' outpu...                3
# 996  [gadget_id='calculator' inputs='75 - 19' outpu...               56
# 997  [gadget_id='calculator' inputs='55 / 15' outpu...              220
# 998  [gadget_id='calculator' inputs='7 - 4' outputs...                3
# 999  [gadget_id='calculator' inputs='13 - 2' output...               11
#
# [1000 rows x 7 columns]

# %%
df[df["answer"] != df["evaluated_result"]]
# Out:
#            id                                           question  \
# 679  chal-680  Rachel's tree had 4 apples. She picked 2 apple...
#
#                     equation  answer      type  \
# 679  ( ( 4.0 - 2.0 ) + 3.0 )       1  Addition
#
#                                                  chain evaluated_result
# 679  [gadget_id='calculator' inputs='4 - 2' outputs...                5

# %%
df["result"] = df["evaluated_result"].apply(calc.format_sympy_number, add_approx=False)
df["result_float"] = df["result"].apply(calc._float_eval)
del df["evaluated_result"]

# %%
df["chain"] = df.apply(lambda row: gadgets.markup.to_model_markup(chain=row["chain"], result=str(row["answer"])), axis=1)
df["chain"]
# Out:
# 0                    [\n, [76 - 25], \n, [51], \n, [51]]
# 1                        [\n, [4 - 3], \n, [1], \n, [1]]
# 2                     [\n, [26 - 9], \n, [17], \n, [17]]
# 3                    [\n, [43 - 21], \n, [22], \n, [22]]
# 4                      [\n, [30 - 28], \n, [2], \n, [2]]
#                              ...
# 995                    [\n, [36 / 12], \n, [3], \n, [3]]
# 996                  [\n, [75 - 19], \n, [56], \n, [56]]
# 997    [\n, [55 / 15], \n, [11/3 = around 3.666667], ...
# 998                      [\n, [7 - 4], \n, [3], \n, [3]]
# 999                   [\n, [13 - 2], \n, [11], \n, [11]]
# Name: chain, Length: 1000, dtype: object

# %%
df["chain"] = df["chain"].apply(str).str.strip()

# %%
df["result_float"] == df["result_float"].apply(round)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: result_float, Length: 1000, dtype: bool

# %%
df
# Out:
#             id                                           question  \
# 0       chal-1  Each pack of dvds costs 76 dollars. If there i...
# 1       chal-2  Dan had $ 3 left with him after he bought a ca...
# 2       chal-3  Paco had 26 salty cookies and 17 sweet cookies...
# 3       chal-4  43 children were riding on the bus. At the bus...
# 4       chal-5  28 children were riding on the bus. At the bus...
# ..         ...                                                ...
# 995   chal-996  Paige was helping her mom plant flowers and to...
# 996   chal-997  At the zoo, a cage had 3 snakes and 75 alligat...
# 997   chal-998  Paige was helping her mom plant flowers and to...
# 998   chal-999  Mary is baking a cake. The recipe calls for 7 ...
# 999  chal-1000  The grasshopper and the frog had a jumping con...
#
#                        equation  answer             type  \
# 0               ( 76.0 - 25.0 )      51      Subtraction
# 1                 ( 4.0 - 3.0 )       1      Subtraction
# 2                ( 26.0 - 9.0 )      17      Subtraction
# 3               ( 43.0 - 21.0 )      22      Subtraction
# 4               ( 30.0 - 28.0 )       2      Subtraction
# ..                          ...     ...              ...
# 995             ( 36.0 / 12.0 )       3  Common-Division
# 996             ( 75.0 - 19.0 )      56      Subtraction
# 997  ( 60.0 * ( 55.0 / 15.0 ) )     220   Multiplication
# 998               ( 7.0 - 4.0 )       3      Subtraction
# 999              ( 13.0 - 2.0 )      11      Subtraction
#
#                                                  chain result  result_float
# 0    <gadget id="calculator">76 - 25</gadget>\n<out...     51          51.0
# 1    <gadget id="calculator">4 - 3</gadget>\n<outpu...      1           1.0
# 2    <gadget id="calculator">26 - 9</gadget>\n<outp...     17          17.0
# 3    <gadget id="calculator">43 - 21</gadget>\n<out...     22          22.0
# 4    <gadget id="calculator">30 - 28</gadget>\n<out...      2           2.0
# ..                                                 ...    ...           ...
# 995  <gadget id="calculator">36 / 12</gadget>\n<out...      3           3.0
# 996  <gadget id="calculator">75 - 19</gadget>\n<out...     56          56.0
# 997  <gadget id="calculator">55 / 15</gadget>\n<out...    220         220.0
# 998  <gadget id="calculator">7 - 4</gadget>\n<outpu...      3           3.0
# 999  <gadget id="calculator">13 - 2</gadget>\n<outp...     11          11.0
#
# [1000 rows x 8 columns]

# %%
df = df.from_dict({
    "id": df["id"],
    "question": df["question"],
    "chain": df["chain"],
    "result": df["result"],
    "result_float": df["result_float"],
    "equation": df["equation"],
    "problem_type": df["type"],
})

# %%
df
# Out:
#             id                                           question  \
# 0       chal-1  Each pack of dvds costs 76 dollars. If there i...
# 1       chal-2  Dan had $ 3 left with him after he bought a ca...
# 2       chal-3  Paco had 26 salty cookies and 17 sweet cookies...
# 3       chal-4  43 children were riding on the bus. At the bus...
# 4       chal-5  28 children were riding on the bus. At the bus...
# ..         ...                                                ...
# 995   chal-996  Paige was helping her mom plant flowers and to...
# 996   chal-997  At the zoo, a cage had 3 snakes and 75 alligat...
# 997   chal-998  Paige was helping her mom plant flowers and to...
# 998   chal-999  Mary is baking a cake. The recipe calls for 7 ...
# 999  chal-1000  The grasshopper and the frog had a jumping con...
#
#                                                  chain result  result_float  \
# 0    <gadget id="calculator">76 - 25</gadget>\n<out...     51          51.0
# 1    <gadget id="calculator">4 - 3</gadget>\n<outpu...      1           1.0
# 2    <gadget id="calculator">26 - 9</gadget>\n<outp...     17          17.0
# 3    <gadget id="calculator">43 - 21</gadget>\n<out...     22          22.0
# 4    <gadget id="calculator">30 - 28</gadget>\n<out...      2           2.0
# ..                                                 ...    ...           ...
# 995  <gadget id="calculator">36 / 12</gadget>\n<out...      3           3.0
# 996  <gadget id="calculator">75 - 19</gadget>\n<out...     56          56.0
# 997  <gadget id="calculator">55 / 15</gadget>\n<out...    220         220.0
# 998  <gadget id="calculator">7 - 4</gadget>\n<outpu...      3           3.0
# 999  <gadget id="calculator">13 - 2</gadget>\n<outp...     11          11.0
#
#                        equation     problem_type
# 0               ( 76.0 - 25.0 )      Subtraction
# 1                 ( 4.0 - 3.0 )      Subtraction
# 2                ( 26.0 - 9.0 )      Subtraction
# 3               ( 43.0 - 21.0 )      Subtraction
# 4               ( 30.0 - 28.0 )      Subtraction
# ..                          ...              ...
# 995             ( 36.0 / 12.0 )  Common-Division
# 996             ( 75.0 - 19.0 )      Subtraction
# 997  ( 60.0 * ( 55.0 / 15.0 ) )   Multiplication
# 998               ( 7.0 - 4.0 )      Subtraction
# 999              ( 13.0 - 2.0 )      Subtraction
#
# [1000 rows x 7 columns]

# %%
df.to_json("../data/svamp/svamp-processed.jsonl", orient="records", lines=True, force_ascii=False)

# %%
import datasets

datasets.load_dataset("MU-NLPC/Calc-svamp")["test"][0]
# Out:
# Downloading readme:   0%|          | 0.00/2.90k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/404k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# {'id': 'chal-1',
#  'question': 'Each pack of dvds costs 76 dollars. If there is a discount of 25 dollars on each pack, how much do you have to pay to buy each pack?',
#  'chain': '<gadget id="calculator">76 - 25</gadget>\n<output>51</output>\n<result>51</result>',
#  'result': '51',
#  'result_float': 51.0,
#  'equation': '( 76.0 - 25.0 )',
#  'problem_type': 'Subtraction'}
